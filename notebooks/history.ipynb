# %%
import pandas as pd

# %%
file_path = "../data/landing/Moving annual rent by suburb - March quarter 2023 copy.xlsx"

# %%
df_1_bedroom_flat_cleaned = pd.read_excel(file_path, sheet_name='1 bedroom flat', header=[0, 1])
df_1_bedroom_flat_cleaned.columns = [f'{col1} {col2}'.strip() if pd.notna(col1) and pd.notna(col2) else col1 or col2 for col1, col2 in df_1_bedroom_flat_cleaned.columns]
df_1_bedroom_flat_cleaned = df_1_bedroom_flat_cleaned.drop([0])

df_1_bedroom_flat_cleaned.reset_index(drop=True, inplace=True)

df_1_bedroom_flat_cleaned.head()
# Out:
#   Moving annual rent by suburb 1 bedroom flat  \
# 0                             Inner Melbourne
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#   Moving annual rent by suburb 1 bedroom flat.1  \
# 0         Albert Park-Middle Park-West St Kilda
# 1                                      Armadale
# 2                                 Carlton North
# 3                             Carlton-Parkville
# 4                               CBD-St Kilda Rd
#
#   Lease commenced in year ending  Mar 2000  \
# 0                                      352
# 1                                      210
# 2                                       87
# 3                                      303
# 4                                      755
#
#   Lease commenced in year ending  Mar 2000.1  \
# 0                                        165
# 1                                        150
# 2                                        150
# 3                                        165
# 4                                        250
#
#   Lease commenced in year ending  Jun 2000  \
# 0                                      347
# 1                                      212
# 2                                       78
# 3                                      300
# 4                                      861
#
#   Lease commenced in year ending  Jun 2000.1  \
# 0                                        165
# 1                                        150
# 2                                        155
# 3                                        170
# 4                                        250
#
#   Lease commenced in year ending  Sep 2000  \
# 0                                      378
# 1                                      213
# 2                                       74
# 3                                      315
# 4                                      934
#
#   Lease commenced in year ending  Sep 2000.1  \
# 0                                        170
# 1                                        155
# 2                                        150
# 3                                        175
# 4                                        250
#
#   Lease commenced in year ending  Dec 2000  \
# 0                                      369
# 1                                      213
# 2                                       65
# 3                                      351
# 4                                      952
#
#   Lease commenced in year ending  Dec 2000.1  ...  \
# 0                                        175  ...
# 1                                        160  ...
# 2                                        150  ...
# 3                                        180  ...
# 4                                        250  ...
#
#   Lease commenced in year ending  Mar 2022  \
# 0                                      269
# 1                                      223
# 2                                       79
# 3                                     3516
# 4                                     8769
#
#   Lease commenced in year ending  Mar 2022.1  \
# 0                                        315
# 1                                        310
# 2                                        300
# 3                                        259
# 4                                        320
#
#   Lease commenced in year ending  Jun 2022  \
# 0                                      262
# 1                                      233
# 2                                       68
# 3                                     3544
# 4                                     8619
#
#   Lease commenced in year ending  Jun 2022.1  \
# 0                                        325
# 1                                        320
# 2                                        320
# 3                                        269
# 4                                        340
#
#   Lease commenced in year ending  Sep 2022  \
# 0                                      277
# 1                                      237
# 2                                       72
# 3                                     4296
# 4                                     9913
#
#   Lease commenced in year ending  Sep 2022.1  \
# 0                                        340
# 1                                        340
# 2                                        320
# 3                                        300
# 4                                        365
#
#   Lease commenced in year ending  Dec 2022  \
# 0                                      260
# 1                                      238
# 2                                       71
# 3                                     4203
# 4                                     9638
#
#   Lease commenced in year ending  Dec 2022.1  \
# 0                                        350
# 1                                        350
# 2                                        330
# 3                                        309
# 4                                        390
#
#   Lease commenced in year ending  Mar 2023  \
# 0                                      262
# 1                                      204
# 2                                       64
# 3                                     4488
# 4                                     9781
#
#   Lease commenced in year ending  Mar 2023.1
# 0                                        360
# 1                                        360
# 2                                        373
# 3                                        352
# 4                                        430
#
# [5 rows x 188 columns]

# %%
# Create separate DataFrames for Count and Median
count_df = df_1_bedroom_flat_cleaned[[col for col in df_1_bedroom_flat_cleaned.columns if '.1' not in col]+['Moving annual rent by suburb 1 bedroom flat.1']]
median_df = df_1_bedroom_flat_cleaned[[col for col in df_1_bedroom_flat_cleaned.columns if '.1' in col]+['Moving annual rent by suburb 1 bedroom flat.1']]

# Rename the columns in the Median DataFrame to remove the '.1'
median_df.columns = [col.replace('.1', '').strip() for col in median_df.columns]

# Optionally reset index to clean both DataFrames
count_df.reset_index(drop=True, inplace=True)
median_df.reset_index(drop=True, inplace=True)

count_df
# Out:
#     Moving annual rent by suburb 1 bedroom flat  \
# 0                               Inner Melbourne
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ..                                          ...
# 154                                         NaN
# 155                                         NaN
# 156                                         NaN
# 157                                         NaN
# 158                                         NaN
#
#     Lease commenced in year ending  Mar 2000  \
# 0                                        352
# 1                                        210
# 2                                         87
# 3                                        303
# 4                                        755
# ..                                       ...
# 154                                       51
# 155                                       13
# 156                                      113
# 157                                       77
# 158                                     1132
#
#     Lease commenced in year ending  Jun 2000  \
# 0                                        347
# 1                                        212
# 2                                         78
# 3                                        300
# 4                                        861
# ..                                       ...
# 154                                       46
# 155                                       11
# 156                                      104
# 157                                       72
# 158                                     1125
#
#     Lease commenced in year ending  Sep 2000  \
# 0                                        378
# 1                                        213
# 2                                         74
# 3                                        315
# 4                                        934
# ..                                       ...
# 154                                       44
# 155                                       12
# 156                                      108
# 157                                       77
# 158                                     1148
#
#     Lease commenced in year ending  Dec 2000  \
# 0                                        369
# 1                                        213
# 2                                         65
# 3                                        351
# 4                                        952
# ..                                       ...
# 154                                       47
# 155                                       10
# 156                                      105
# 157                                       83
# 158                                     1149
#
#     Lease commenced in year ending  Mar 2001  \
# 0                                        395
# 1                                        206
# 2                                         73
# 3                                        360
# 4                                       1145
# ..                                       ...
# 154                                       44
# 155                                       13
# 156                                       97
# 157                                       87
# 158                                     1169
#
#     Lease commenced in year ending  Jun 2001  \
# 0                                        411
# 1                                        198
# 2                                         78
# 3                                        393
# 4                                       1155
# ..                                       ...
# 154                                       40
# 155                                       14
# 156                                      105
# 157                                       88
# 158                                     1163
#
#     Lease commenced in year ending  Sep 2001  \
# 0                                        405
# 1                                        195
# 2                                         73
# 3                                        381
# 4                                       1231
# ..                                       ...
# 154                                       35
# 155                                       10
# 156                                      102
# 157                                       80
# 158                                     1190
#
#     Lease commenced in year ending  Dec 2001  \
# 0                                        423
# 1                                        191
# 2                                         73
# 3                                        345
# 4                                       1383
# ..                                       ...
# 154                                       36
# 155                                       10
# 156                                      103
# 157                                       75
# 158                                     1173
#
#     Lease commenced in year ending  Mar 2002  ...  \
# 0                                        424  ...
# 1                                        194  ...
# 2                                         71  ...
# 3                                        399  ...
# 4                                       1463  ...
# ..                                       ...  ...
# 154                                       36  ...
# 155                                        -  ...
# 156                                      104  ...
# 157                                       67  ...
# 158                                     1138  ...
#
#     Lease commenced in year ending  Mar 2021  \
# 0                                        271
# 1                                        208
# 2                                         72
# 3                                       2149
# 4                                       7065
# ..                                       ...
# 154                                       53
# 155                                        -
# 156                                       57
# 157                                       61
# 158                                      833
#
#     Lease commenced in year ending  Jun 2021  \
# 0                                        283
# 1                                        227
# 2                                         82
# 3                                       2469
# 4                                       7718
# ..                                       ...
# 154                                       51
# 155                                        -
# 156                                       55
# 157                                       57
# 158                                      827
#
#     Lease commenced in year ending  Sep 2021  \
# 0                                        290
# 1                                        239
# 2                                         77
# 3                                       2609
# 4                                       7843
# ..                                       ...
# 154                                       50
# 155                                        -
# 156                                       48
# 157                                       54
# 158                                      828
#
#     Lease commenced in year ending  Dec 2021  \
# 0                                        299
# 1                                        226
# 2                                         80
# 3                                       2773
# 4                                       7802
# ..                                       ...
# 154                                       44
# 155                                        -
# 156                                       54
# 157                                       49
# 158                                      811
#
#     Lease commenced in year ending  Mar 2022  \
# 0                                        269
# 1                                        223
# 2                                         79
# 3                                       3516
# 4                                       8769
# ..                                       ...
# 154                                       36
# 155                                        -
# 156                                       57
# 157                                       43
# 158                                      769
#
#     Lease commenced in year ending  Jun 2022  \
# 0                                        262
# 1                                        233
# 2                                         68
# 3                                       3544
# 4                                       8619
# ..                                       ...
# 154                                       33
# 155                                        -
# 156                                       59
# 157                                       36
# 158                                      723
#
#     Lease commenced in year ending  Sep 2022  \
# 0                                        277
# 1                                        237
# 2                                         72
# 3                                       4296
# 4                                       9913
# ..                                       ...
# 154                                       35
# 155                                        -
# 156                                       65
# 157                                       44
# 158                                      717
#
#     Lease commenced in year ending  Dec 2022  \
# 0                                        260
# 1                                        238
# 2                                         71
# 3                                       4203
# 4                                       9638
# ..                                       ...
# 154                                       41
# 155                                        -
# 156                                       60
# 157                                       51
# 158                                      708
#
#     Lease commenced in year ending  Mar 2023  \
# 0                                        262
# 1                                        204
# 2                                         64
# 3                                       4488
# 4                                       9781
# ..                                       ...
# 154                                       42
# 155                                        -
# 156                                       59
# 157                                       51
# 158                                      736
#
#     Moving annual rent by suburb 1 bedroom flat.1
# 0           Albert Park-Middle Park-West St Kilda
# 1                                        Armadale
# 2                                   Carlton North
# 3                               Carlton-Parkville
# 4                                 CBD-St Kilda Rd
# ..                                            ...
# 154                                   Wanagaratta
# 155                                      Warragul
# 156                                   Warrnambool
# 157                                       Wodonga
# 158                                   Group Total
#
# [159 rows x 96 columns]

# %%
import re

def extract_date(col_name):
    match = re.findall(r'Lease commenced in year ending  (\w{3} \d{4})', col_name)
    if match:
        return match[0] 
    return col_name 

count_df = df_1_bedroom_flat_cleaned[[col for col in df_1_bedroom_flat_cleaned.columns if '.1' not in col] + ['Moving annual rent by suburb 1 bedroom flat.1']]
median_df = df_1_bedroom_flat_cleaned[[col for col in df_1_bedroom_flat_cleaned.columns if '.1' in col]+ ['Moving annual rent by suburb 1 bedroom flat.1']]
count_df.head(2)
# Out:
#   Moving annual rent by suburb 1 bedroom flat  \
# 0                             Inner Melbourne
# 1                                         NaN
#
#   Lease commenced in year ending  Mar 2000  \
# 0                                      352
# 1                                      210
#
#   Lease commenced in year ending  Jun 2000  \
# 0                                      347
# 1                                      212
#
#   Lease commenced in year ending  Sep 2000  \
# 0                                      378
# 1                                      213
#
#   Lease commenced in year ending  Dec 2000  \
# 0                                      369
# 1                                      213
#
#   Lease commenced in year ending  Mar 2001  \
# 0                                      395
# 1                                      206
#
#   Lease commenced in year ending  Jun 2001  \
# 0                                      411
# 1                                      198
#
#   Lease commenced in year ending  Sep 2001  \
# 0                                      405
# 1                                      195
#
#   Lease commenced in year ending  Dec 2001  \
# 0                                      423
# 1                                      191
#
#   Lease commenced in year ending  Mar 2002  ...  \
# 0                                      424  ...
# 1                                      194  ...
#
#   Lease commenced in year ending  Mar 2021  \
# 0                                      271
# 1                                      208
#
#   Lease commenced in year ending  Jun 2021  \
# 0                                      283
# 1                                      227
#
#   Lease commenced in year ending  Sep 2021  \
# 0                                      290
# 1                                      239
#
#   Lease commenced in year ending  Dec 2021  \
# 0                                      299
# 1                                      226
#
#   Lease commenced in year ending  Mar 2022  \
# 0                                      269
# 1                                      223
#
#   Lease commenced in year ending  Jun 2022  \
# 0                                      262
# 1                                      233
#
#   Lease commenced in year ending  Sep 2022  \
# 0                                      277
# 1                                      237
#
#   Lease commenced in year ending  Dec 2022  \
# 0                                      260
# 1                                      238
#
#   Lease commenced in year ending  Mar 2023  \
# 0                                      262
# 1                                      204
#
#   Moving annual rent by suburb 1 bedroom flat.1
# 0         Albert Park-Middle Park-West St Kilda
# 1                                      Armadale
#
# [2 rows x 96 columns]

# %%
print(count_df.columns)
# Out:
# Index(['Moving annual rent by suburb 1 bedroom flat',
#        'Lease commenced in year ending  Mar 2000',
#        'Lease commenced in year ending  Jun 2000',
#        'Lease commenced in year ending  Sep 2000',
#        'Lease commenced in year ending  Dec 2000',
#        'Lease commenced in year ending  Mar 2001',
#        'Lease commenced in year ending  Jun 2001',
#        'Lease commenced in year ending  Sep 2001',
#        'Lease commenced in year ending  Dec 2001',
#        'Lease commenced in year ending  Mar 2002',
#        'Lease commenced in year ending  Jun 2002',
#        'Lease commenced in year ending  Sep 2002',
#        'Lease commenced in year ending  Dec 2003',
#        'Lease commenced in year ending  Mar 2003',
#        'Lease commenced in year ending  Jun 2003',
#        'Lease commenced in year ending  Sep 2003',
#        'Lease commenced in year ending  Dec 2003.2',
#        'Lease commenced in year ending  Dec 2003.3',
#        'Lease commenced in year ending  Mar 2004',
#        'Lease commenced in year ending  Jun 2004',
#        'Lease commenced in year ending  Sep 2004',
#        'Lease commenced in year ending  Dec 2004',
#        'Lease commenced in year ending  Mar 2005',
#        'Lease commenced in year ending  Jun 2005',
#        'Lease commenced in year ending  Sep 2005',
#        'Lease commenced in year ending  Dec 2005',
#        'Lease commenced in year ending  Mar 2006',
#        'Lease commenced in year ending  Jun 2006',
#        'Lease commenced in year ending  Sep 2006',
#        'Lease commenced in year ending  Dec 2006',
#        'Lease commenced in year ending  Mar 2007',
#        'Lease commenced in year ending  Jun 2007',
#        'Lease commenced in year ending  Sep 2007',
#        'Lease commenced in year ending  Dec 2007',
#        'Lease commenced in year ending  Mar 2008',
#        'Lease commenced in year ending  Jun 2008',
#        'Lease commenced in year ending  Sep 2008',
#        'Lease commenced in year ending  Dec 2008',
#        'Lease commenced in year ending  Mar 2009',
#        'Lease commenced in year ending  Jun 2009',
#        'Lease commenced in year ending  Sep 2009',
#        'Lease commenced in year ending  Dec 2009',
#        'Lease commenced in year ending  Mar 2010',
#        'Lease commenced in year ending  Jun 2010',
#        'Lease commenced in year ending  Sep 2010',
#        'Lease commenced in year ending  Dec 2010',
#        'Lease commenced in year ending  Mar 2011',
#        'Lease commenced in year ending  Jun 2011',
#        'Lease commenced in year ending  Sep 2011',
#        'Lease commenced in year ending  Dec 2011',
#        'Lease commenced in year ending  Mar 2012',
#        'Lease commenced in year ending  Jun 2012',
#        'Lease commenced in year ending  Sep 2012',
#        'Lease commenced in year ending  Dec 2012',
#        'Lease commenced in year ending  Mar 2013',
#        'Lease commenced in year ending  Jun 2013',
#        'Lease commenced in year ending  Sep 2013',
#        'Lease commenced in year ending  Dec 2013',
#        'Lease commenced in year ending  Mar 2014',
#        'Lease commenced in year ending  Jun 2014',
#        'Lease commenced in year ending  Sep 2014',
#        'Lease commenced in year ending  Dec 2014',
#        'Lease commenced in year ending  Mar 2015',
#        'Lease commenced in year ending  Jun 2015',
#        'Lease commenced in year ending  Sep 2015',
#        'Lease commenced in year ending  Dec 2015',
#        'Lease commenced in year ending  Mar 2016',
#        'Lease commenced in year ending  Jun 2016',
#        'Lease commenced in year ending  Sep 2016',
#        'Lease commenced in year ending  Dec 2016',
#        'Lease commenced in year ending  Mar 2017',
#        'Lease commenced in year ending  Jun 2017',
#        'Lease commenced in year ending  Sep 2017',
#        'Lease commenced in year ending  Dec 2017',
#        'Lease commenced in year ending  Mar 2018',
#        'Lease commenced in year ending  Jun 2018',
#        'Lease commenced in year ending  Sep 2018',
#        'Lease commenced in year ending  Dec 2018',
#        'Lease commenced in year ending  Mar 2019',
#        'Lease commenced in year ending  Jun 2019',
#        'Lease commenced in year ending  Sep 2019',
#        'Lease commenced in year ending  Dec 2019',
#        'Lease commenced in year ending  Mar 2020',
#        'Lease commenced in year ending  Jun 2020',
#        'Lease commenced in year ending  Sep 2020',
#        'Lease commenced in year ending  Dec 2020',
#        'Lease commenced in year ending  Mar 2021',
#        'Lease commenced in year ending  Jun 2021',
#        'Lease commenced in year ending  Sep 2021',
#        'Lease commenced in year ending  Dec 2021',
#        'Lease commenced in year ending  Mar 2022',
#        'Lease commenced in year ending  Jun 2022',
#        'Lease commenced in year ending  Sep 2022',
#        'Lease commenced in year ending  Dec 2022',
#        'Lease commenced in year ending  Mar 2023',
#        'Moving annual rent by suburb 1 bedroom flat.1'],
#       dtype='object')

# %%
count_df.columns = [extract_date(col) for col in count_df.columns]
count_df = count_df.rename({'Moving annual rent by suburb 1 bedroom flat': 'Suburb', 'Moving annual rent by suburb 1 bedroom flat.1':'Region'}, axis=1)
median_df.columns = [extract_date(col.replace('.1', '')) for col in median_df.columns]
median_df = median_df.rename({'Moving annual rent by suburb 1 bedroom flat': 'Suburb', 'Moving annual rent by suburb 1 bedroom flat.1':'Region'}, axis=1)

# %%
count_df.columns
median_df.columns
# Out:
# Index(['Suburb', 'Mar 2000', 'Jun 2000', 'Sep 2000', 'Dec 2000', 'Mar 2001',
#        'Jun 2001', 'Sep 2001', 'Dec 2001', 'Mar 2002', 'Jun 2002', 'Sep 2002',
#        'Dec 2003', 'Mar 2003', 'Jun 2003', 'Sep 2003', 'Mar 2004', 'Jun 2004',
#        'Sep 2004', 'Dec 2004', 'Mar 2005', 'Jun 2005', 'Sep 2005', 'Dec 2005',
#        'Mar 2006', 'Jun 2006', 'Sep 2006', 'Dec 2006', 'Mar 2007', 'Jun 2007',
#        'Sep 2007', 'Dec 2007', 'Mar 2008', 'Jun 2008', 'Sep 2008', 'Dec 2008',
#        'Mar 2009', 'Jun 2009', 'Sep 2009', 'Dec 2009', 'Mar 2010', 'Jun 2010',
#        'Sep 2010', 'Dec 2010', 'Mar 2011', 'Jun 2011', 'Sep 2011', 'Dec 2011',
#        'Mar 2012', 'Jun 2012', 'Sep 2012', 'Dec 2012', 'Mar 2013', 'Jun 2013',
#        'Sep 2013', 'Dec 2013', 'Mar 2014', 'Jun 2014', 'Sep 2014', 'Dec 2014',
#        'Mar 2015', 'Jun 2015', 'Sep 2015', 'Dec 2015', 'Mar 2016', 'Jun 2016',
#        'Sep 2016', 'Dec 2016', 'Mar 2017', 'Jun 2017', 'Sep 2017', 'Dec 2017',
#        'Mar 2018', 'Jun 2018', 'Sep 2018', 'Dec 2018', 'Mar 2019', 'Jun 2019',
#        'Sep 2019', 'Dec 2019', 'Mar 2020', 'Jun 2020', 'Sep 2020', 'Dec 2020',
#        'Mar 2021', 'Jun 2021', 'Sep 2021', 'Dec 2021', 'Mar 2022', 'Jun 2022',
#        'Sep 2022', 'Dec 2022', 'Mar 2023', 'Suburb'],
#       dtype='object')

# %%
count_df
# Out:
#               Suburb Mar 2000 Jun 2000 Sep 2000 Dec 2000 Mar 2001 Jun 2001  \
# 0    Inner Melbourne      352      347      378      369      395      411
# 1                NaN      210      212      213      213      206      198
# 2                NaN       87       78       74       65       73       78
# 3                NaN      303      300      315      351      360      393
# 4                NaN      755      861      934      952     1145     1155
# ..               ...      ...      ...      ...      ...      ...      ...
# 154              NaN       51       46       44       47       44       40
# 155              NaN       13       11       12       10       13       14
# 156              NaN      113      104      108      105       97      105
# 157              NaN       77       72       77       83       87       88
# 158              NaN     1132     1125     1148     1149     1169     1163
#
#     Sep 2001 Dec 2001 Mar 2002  ... Mar 2021 Jun 2021 Sep 2021 Dec 2021  \
# 0        405      423      424  ...      271      283      290      299
# 1        195      191      194  ...      208      227      239      226
# 2         73       73       71  ...       72       82       77       80
# 3        381      345      399  ...     2149     2469     2609     2773
# 4       1231     1383     1463  ...     7065     7718     7843     7802
# ..       ...      ...      ...  ...      ...      ...      ...      ...
# 154       35       36       36  ...       53       51       50       44
# 155       10       10        -  ...        -        -        -        -
# 156      102      103      104  ...       57       55       48       54
# 157       80       75       67  ...       61       57       54       49
# 158     1190     1173     1138  ...      833      827      828      811
#
#     Mar 2022 Jun 2022 Sep 2022 Dec 2022 Mar 2023  \
# 0        269      262      277      260      262
# 1        223      233      237      238      204
# 2         79       68       72       71       64
# 3       3516     3544     4296     4203     4488
# 4       8769     8619     9913     9638     9781
# ..       ...      ...      ...      ...      ...
# 154       36       33       35       41       42
# 155        -        -        -        -        -
# 156       57       59       65       60       59
# 157       43       36       44       51       51
# 158      769      723      717      708      736
#
#                                     Region
# 0    Albert Park-Middle Park-West St Kilda
# 1                                 Armadale
# 2                            Carlton North
# 3                        Carlton-Parkville
# 4                          CBD-St Kilda Rd
# ..                                     ...
# 154                            Wanagaratta
# 155                               Warragul
# 156                            Warrnambool
# 157                                Wodonga
# 158                            Group Total
#
# [159 rows x 96 columns]

# %%
count_df_calc = count_df.drop("Suburb", axis=1)
count_df_calc.to_csv("../data/curated/1b1bhistory.csv", index=False)

# %%
def growth_rate:
# Out:
# Index(['Mar 2000', 'Jun 2000', 'Sep 2000', 'Dec 2000', 'Mar 2001', 'Jun 2001',
#        'Sep 2001', 'Dec 2001', 'Mar 2002', 'Jun 2002', 'Sep 2002', 'Dec 2003',
#        'Mar 2003', 'Jun 2003', 'Sep 2003', 'Dec 2003', 'Dec 2003', 'Mar 2004',
#        'Jun 2004', 'Sep 2004', 'Dec 2004', 'Mar 2005', 'Jun 2005', 'Sep 2005',
#        'Dec 2005', 'Mar 2006', 'Jun 2006', 'Sep 2006', 'Dec 2006', 'Mar 2007',
#        'Jun 2007', 'Sep 2007', 'Dec 2007', 'Mar 2008', 'Jun 2008', 'Sep 2008',
#        'Dec 2008', 'Mar 2009', 'Jun 2009', 'Sep 2009', 'Dec 2009', 'Mar 2010',
#        'Jun 2010', 'Sep 2010', 'Dec 2010', 'Mar 2011', 'Jun 2011', 'Sep 2011',
#        'Dec 2011', 'Mar 2012', 'Jun 2012', 'Sep 2012', 'Dec 2012', 'Mar 2013',
#        'Jun 2013', 'Sep 2013', 'Dec 2013', 'Mar 2014', 'Jun 2014', 'Sep 2014',
#        'Dec 2014', 'Mar 2015', 'Jun 2015', 'Sep 2015', 'Dec 2015', 'Mar 2016',
#        'Jun 2016', 'Sep 2016', 'Dec 2016', 'Mar 2017', 'Jun 2017', 'Sep 2017',
#        'Dec 2017', 'Mar 2018', 'Jun 2018', 'Sep 2018', 'Dec 2018', 'Mar 2019',
#        'Jun 2019', 'Sep 2019', 'Dec 2019', 'Mar 2020', 'Jun 2020', 'Sep 2020',
#        'Dec 2020', 'Mar 2021', 'Jun 2021', 'Sep 2021', 'Dec 2021', 'Mar 2022',
#        'Jun 2022', 'Sep 2022', 'Dec 2022', 'Mar 2023', 'Region',
#        'Growth_Rate_Jun 2000_to_2023'],
#       dtype='object')
# Top 10 suburbs for Jun 2000 to 2023:
#                               Region  Growth_Rate_Jun 2000_to_2023
# 19                         Southbank                   1469.811321
# 3                  Carlton-Parkville                   1396.000000
# 13    North Melbourne-West Melbourne                   1296.951220
# 30                Chadstone-Oakleigh                   1113.333333
# 31                           Clayton                   1088.095238
# 4                    CBD-St Kilda Rd                   1036.004646
# 25                          Box Hill                    615.294118
# 17                   South Melbourne                    577.922078
# 5             Collingwood-Abbotsford                    573.228346
# 107  Dandenong North-Endeavour Hills                    566.666667
#
#
# Index(['Mar 2000', 'Jun 2000', 'Sep 2000', 'Dec 2000', 'Mar 2001', 'Jun 2001',
#        'Sep 2001', 'Dec 2001', 'Mar 2002', 'Jun 2002', 'Sep 2002', 'Dec 2003',
#        'Mar 2003', 'Jun 2003', 'Sep 2003', 'Dec 2003', 'Dec 2003', 'Mar 2004',
#        'Jun 2004', 'Sep 2004', 'Dec 2004', 'Mar 2005', 'Jun 2005', 'Sep 2005',
#        'Dec 2005', 'Mar 2006', 'Jun 2006', 'Sep 2006', 'Dec 2006', 'Mar 2007',
#        'Jun 2007', 'Sep 2007', 'Dec 2007', 'Mar 2008', 'Jun 2008', 'Sep 2008',
#        'Dec 2008', 'Mar 2009', 'Jun 2009', 'Sep 2009', 'Dec 2009', 'Mar 2010',
#        'Jun 2010', 'Sep 2010', 'Dec 2010', 'Mar 2011', 'Jun 2011', 'Sep 2011',
#        'Dec 2011', 'Mar 2012', 'Jun 2012', 'Sep 2012', 'Dec 2012', 'Mar 2013',
#        'Jun 2013', 'Sep 2013', 'Dec 2013', 'Mar 2014', 'Jun 2014', 'Sep 2014',
#        'Dec 2014', 'Mar 2015', 'Jun 2015', 'Sep 2015', 'Dec 2015', 'Mar 2016',
#        'Jun 2016', 'Sep 2016', 'Dec 2016', 'Mar 2017', 'Jun 2017', 'Sep 2017',
#        'Dec 2017', 'Mar 2018', 'Jun 2018', 'Sep 2018', 'Dec 2018', 'Mar 2019',
#        'Jun 2019', 'Sep 2019', 'Dec 2019', 'Mar 2020', 'Jun 2020', 'Sep 2020',
#        'Dec 2020', 'Mar 2021', 'Jun 2021', 'Sep 2021', 'Dec 2021', 'Mar 2022',
#        'Jun 2022', 'Sep 2022', 'Dec 2022', 'Mar 2023', 'Region',
#        'Growth_Rate_Sep 2000_to_2023'],
#       dtype='object')
# Top 10 suburbs for Sep 2000 to 2023:
#                               Region  Growth_Rate_Sep 2000_to_2023
# 19                         Southbank                   1385.714286
# 3                  Carlton-Parkville                   1324.761905
# 13    North Melbourne-West Melbourne                   1288.484848
# 4                    CBD-St Kilda Rd                    947.216274
# 31                           Clayton                    939.583333
# 30                Chadstone-Oakleigh                    857.894737
# 107  Dandenong North-Endeavour Hills                    700.000000
# 72                    East Brunswick                    611.666667
# 25                          Box Hill                    598.850575
# 49                 Hampton-Beaumaris                    571.428571
#
#
# Index(['Mar 2000', 'Jun 2000', 'Sep 2000', 'Dec 2000', 'Mar 2001', 'Jun 2001',
# Top 10 suburbs for Sep 2002 to 2023:
#                             Region  Growth_Rate_Sep 2002_to_2023
# 6                        Docklands                   3568.750000
# 27               Burwood-Ashburton                   3190.000000
# 13  North Melbourne-West Melbourne                   1239.766082
# 30              Chadstone-Oakleigh                   1113.333333
# 3                Carlton-Parkville                   1074.869110
# 19                       Southbank                    824.444444
# 72                  East Brunswick                    789.583333
# 31                         Clayton                    718.032787
# 25                        Box Hill                    598.850575
# 4                  CBD-St Kilda Rd                    566.280654
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [112], in <cell line: 1>()
#       1 for year in count_df_calc.columns[1:-1]:
#       2     count_df_calc[year] = count_df_calc[year].replace('-', pd.NA).astype(pd.Float64Dtype())
# ----> 4     valid_rows = count_df_calc[~count_df_calc[year].isna()]
#       6     if valid_rows.empty:
#       7         print(f"No valid data for year {year}, skipping...\n")
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/frame.py:3883, in __getitem__(self, key)
#    3879 dtypes = list(self.dtypes)
#    3881 if self._can_fast_transpose:
#    3882     # Note: tests pass without this, but this improves perf quite a bit.
# -> 3883     new_vals = self._values.T
#    3884     if copy and not using_copy_on_write():
#    3885         new_vals = new_vals.copy()
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/generic.py:10600, in where(self, cond, other, inplace, axis, level)
#   10598         right = other.copy(deep=copy)
#   10599     else:
# > 10600         right = other.reindex(join_index, level=level)
#   10602 # fill
#   10603 fill_na = notna(fill_value) or (method is not None)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/generic.py:10318, in _where(self, cond, other, inplace, axis, level)
#   10185 @final
#   10186 @doc(
#   10187     klass=_shared_doc_kwargs["klass"],
#    (...)
#   10201     broadcast_axis: Axis | None | lib.NoDefault = lib.no_default,
#   10202 ) -> tuple[Self, NDFrameT]:
#   10203     """
#   10204     Align two objects on their axes with the specified join method.
#   10205
#   10206     Join method is specified for each axis Index.
#   10207
#   10208     Parameters
#   10209     ----------
#   10210     other : DataFrame or Series
#   10211     join : {{'outer', 'inner', 'left', 'right'}}, default 'outer'
#   10212         Type of alignment to be performed.
#   10213
#   10214         * left: use only keys from left frame, preserve key order.
#   10215         * right: use only keys from right frame, preserve key order.
#   10216         * outer: use union of keys from both frames, sort keys lexicographically.
#   10217         * inner: use intersection of keys from both frames,
#   10218           preserve the order of the left keys.
#   10219
#   10220     axis : allowed axis of the other object, default None
#   10221         Align on index (0), columns (1), or both (None).
#   10222     level : int or level name, default None
#   10223         Broadcast across a level, matching Index values on the
#   10224         passed MultiIndex level.
#   10225     copy : bool, default True
#   10226         Always returns new objects. If copy=False and no reindexing is
#   10227         required then original objects are returned.
#   10228
#   10229         .. note::
#   10230             The `copy` keyword will change behavior in pandas 3.0.
#   10231             `Copy-on-Write
#   10232             <https://pandas.pydata.org/docs/dev/user_guide/copy_on_write.html>`__
#   10233             will be enabled by default, which means that all methods with a
#   10234             `copy` keyword will use a lazy copy mechanism to defer the copy and
#   10235             ignore the `copy` keyword. The `copy` keyword will be removed in a
#   10236             future version of pandas.
#   10237
#   10238             You can already get the future behavior and improvements through
#   10239             enabling copy on write ``pd.options.mode.copy_on_write = True``
#   10240     fill_value : scalar, default np.nan
#   10241         Value to use for missing values. Defaults to NaN, but can be any
#   10242         "compatible" value.
#   10243     method : {{'backfill', 'bfill', 'pad', 'ffill', None}}, default None
#   10244         Method to use for filling holes in reindexed Series:
#   10245
#   10246         - pad / ffill: propagate last valid observation forward to next valid.
#   10247         - backfill / bfill: use NEXT valid observation to fill gap.
#   10248
#   10249         .. deprecated:: 2.1
#   10250
#   10251     limit : int, default None
#   10252         If method is specified, this is the maximum number of consecutive
#   10253         NaN values to forward/backward fill. In other words, if there is
#   10254         a gap with more than this number of consecutive NaNs, it will only
#   10255         be partially filled. If method is not specified, this is the
#   10256         maximum number of entries along the entire axis where NaNs will be
#   10257         filled. Must be greater than 0 if not None.
#   10258
#   10259         .. deprecated:: 2.1
#   10260
#   10261     fill_axis : {axes_single_arg}, default 0
#   10262         Filling axis, method and limit.
#   10263
#   10264         .. deprecated:: 2.1
#   10265
#   10266     broadcast_axis : {axes_single_arg}, default None
#   10267         Broadcast values along this axis, if aligning two objects of
#   10268         different dimensions.
#   10269
#   10270         .. deprecated:: 2.1
#   10271
#   10272     Returns
#   10273     -------
#   10274     tuple of ({klass}, type of other)
#   10275         Aligned objects.
#   10276
#   10277     Examples
#   10278     --------
#   10279     >>> df = pd.DataFrame(
#   10280     ...     [[1, 2, 3, 4], [6, 7, 8, 9]], columns=["D", "B", "E", "A"], index=[1, 2]
#   10281     ... )
#   10282     >>> other = pd.DataFrame(
#   10283     ...     [[10, 20, 30, 40], [60, 70, 80, 90], [600, 700, 800, 900]],
#   10284     ...     columns=["A", "B", "C", "D"],
#   10285     ...     index=[2, 3, 4],
#   10286     ... )
#   10287     >>> df
#   10288        D  B  E  A
#   10289     1  1  2  3  4
#   10290     2  6  7  8  9
#   10291     >>> other
#   10292         A    B    C    D
#   10293     2   10   20   30   40
#   10294     3   60   70   80   90
#   10295     4  600  700  800  900
#   10296
#   10297     Align on columns:
#   10298
#   10299     >>> left, right = df.align(other, join="outer", axis=1)
#   10300     >>> left
#   10301        A  B   C  D  E
#   10302     1  4  2 NaN  1  3
#   10303     2  9  7 NaN  6  8
#   10304     >>> right
#   10305         A    B    C    D   E
#   10306     2   10   20   30   40 NaN
#   10307     3   60   70   80   90 NaN
#   10308     4  600  700  800  900 NaN
#   10309
#   10310     We can also align on the index:
#   10311
#   10312     >>> left, right = df.align(other, join="outer", axis=0)
#   10313     >>> left
#   10314         D    B    E    A
#   10315     1  1.0  2.0  3.0  4.0
#   10316     2  6.0  7.0  8.0  9.0
#   10317     3  NaN  NaN  NaN  NaN
# > 10318     4  NaN  NaN  NaN  NaN
#   10319     >>> right
#   10320         A      B      C      D
#   10321     1    NaN    NaN    NaN    NaN
#   10322     2   10.0   20.0   30.0   40.0
#   10323     3   60.0   70.0   80.0   90.0
#   10324     4  600.0  700.0  800.0  900.0
#   10325
#   10326     Finally, the default `axis=None` will align on both index and columns:
#   10327
#   10328     >>> left, right = df.align(other, join="outer", axis=None)
#   10329     >>> left
#   10330          A    B   C    D    E
#   10331     1  4.0  2.0 NaN  1.0  3.0
#   10332     2  9.0  7.0 NaN  6.0  8.0
#   10333     3  NaN  NaN NaN  NaN  NaN
#   10334     4  NaN  NaN NaN  NaN  NaN
#   10335     >>> right
#   10336            A      B      C      D   E
#   10337     1    NaN    NaN    NaN    NaN NaN
#   10338     2   10.0   20.0   30.0   40.0 NaN
#   10339     3   60.0   70.0   80.0   90.0 NaN
#   10340     4  600.0  700.0  800.0  900.0 NaN
#   10341     """
#   10342     if (
#   10343         method is not lib.no_default
#   10344         or limit is not lib.no_default
#   10345         or fill_axis is not lib.no_default
#   10346     ):
#   10347         # GH#51856
#   10348         warnings.warn(
#   10349             "The 'method', 'limit', and 'fill_axis' keywords in "
#   10350             f"{type(self).__name__}.align are deprecated and will be removed "
#    (...)
#   10354             stacklevel=find_stack_level(),
#   10355         )
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/frame.py:5144, in reindex(self, labels, index, columns, axis, method, copy, level, fill_value, limit, tolerance)
#    5095 def insert(
#    5096     self,
#    5097     loc: int,
#    (...)
#    5100     allow_duplicates: bool | lib.NoDefault = lib.no_default,
#    5101 ) -> None:
#    5102     """
#    5103     Insert column into DataFrame at specified location.
#    5104
#    5105     Raises a ValueError if `column` is already contained in the DataFrame,
#    5106     unless `allow_duplicates` is set to True.
#    5107
#    5108     Parameters
#    5109     ----------
#    5110     loc : int
#    5111         Insertion index. Must verify 0 <= loc <= len(columns).
#    5112     column : str, number, or hashable object
#    5113         Label of the inserted column.
#    5114     value : Scalar, Series, or array-like
#    5115         Content of the inserted column.
#    5116     allow_duplicates : bool, optional, default lib.no_default
#    5117         Allow duplicate column labels to be created.
#    5118
#    5119     See Also
#    5120     --------
#    5121     Index.insert : Insert new item by index.
#    5122
#    5123     Examples
#    5124     --------
#    5125     >>> df = pd.DataFrame({'col1': [1, 2], 'col2': [3, 4]})
#    5126     >>> df
#    5127        col1  col2
#    5128     0     1     3
#    5129     1     2     4
#    5130     >>> df.insert(1, "newcol", [99, 99])
#    5131     >>> df
#    5132        col1  newcol  col2
#    5133     0     1      99     3
#    5134     1     2      99     4
#    5135     >>> df.insert(0, "col1", [100, 100], allow_duplicates=True)
#    5136     >>> df
#    5137        col1  col1  newcol  col2
#    5138     0   100     1      99     3
#    5139     1   100     2      99     4
#    5140
#    5141     Notice that pandas uses index alignment in case of `value` from type `Series`:
#    5142
#    5143     >>> df.insert(0, "col0", pd.Series([5, 6], index=[1, 2]))
# -> 5144     >>> df
#    5145        col0  col1  col1  newcol  col2
#    5146     0   NaN   100     1      99     3
#    5147     1   5.0   100     2      99     4
#    5148     """
#    5149     if allow_duplicates is lib.no_default:
#    5150         allow_duplicates = False
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/generic.py:5521, in reindex(self, labels, index, columns, axis, method, copy, level, fill_value, limit, tolerance)
#    5343 @doc(
#    5344     klass=_shared_doc_kwargs["klass"],
#    5345     optional_reindex="",
#    (...)
#    5359     tolerance=None,
#    5360 ) -> Self:
#    5361     """
#    5362     Conform {klass} to new index with optional filling logic.
#    5363
#    5364     Places NA/NaN in locations having no value in the previous index. A new object
#    5365     is produced unless the new index is equivalent to the current one and
#    5366     ``copy=False``.
#    5367
#    5368     Parameters
#    5369     ----------
#    5370     {optional_reindex}
#    5371     method : {{None, 'backfill'/'bfill', 'pad'/'ffill', 'nearest'}}
#    5372         Method to use for filling holes in reindexed DataFrame.
#    5373         Please note: this is only applicable to DataFrames/Series with a
#    5374         monotonically increasing/decreasing index.
#    5375
#    5376         * None (default): don't fill gaps
#    5377         * pad / ffill: Propagate last valid observation forward to next
#    5378           valid.
#    5379         * backfill / bfill: Use next valid observation to fill gap.
#    5380         * nearest: Use nearest valid observations to fill gap.
#    5381
#    5382     copy : bool, default True
#    5383         Return a new object, even if the passed indexes are the same.
#    5384
#    5385         .. note::
#    5386             The `copy` keyword will change behavior in pandas 3.0.
#    5387             `Copy-on-Write
#    5388             <https://pandas.pydata.org/docs/dev/user_guide/copy_on_write.html>`__
#    5389             will be enabled by default, which means that all methods with a
#    5390             `copy` keyword will use a lazy copy mechanism to defer the copy and
#    5391             ignore the `copy` keyword. The `copy` keyword will be removed in a
#    5392             future version of pandas.
#    5393
#    5394             You can already get the future behavior and improvements through
#    5395             enabling copy on write ``pd.options.mode.copy_on_write = True``
#    5396     level : int or name
#    5397         Broadcast across a level, matching Index values on the
#    5398         passed MultiIndex level.
#    5399     fill_value : scalar, default np.nan
#    5400         Value to use for missing values. Defaults to NaN, but can be any
#    5401         "compatible" value.
#    5402     limit : int, default None
#    5403         Maximum number of consecutive elements to forward or backward fill.
#    5404     tolerance : optional
#    5405         Maximum distance between original and new labels for inexact
#    5406         matches. The values of the index at the matching locations most
#    5407         satisfy the equation ``abs(index[indexer] - target) <= tolerance``.
#    5408
#    5409         Tolerance may be a scalar value, which applies the same tolerance
#    5410         to all values, or list-like, which applies variable tolerance per
#    5411         element. List-like includes list, tuple, array, Series, and must be
#    5412         the same size as the index and its dtype must exactly match the
#    5413         index's type.
#    5414
#    5415     Returns
#    5416     -------
#    5417     {klass} with changed index.
#    5418
#    5419     See Also
#    5420     --------
#    5421     DataFrame.set_index : Set row labels.
#    5422     DataFrame.reset_index : Remove row labels or move them to new columns.
#    5423     DataFrame.reindex_like : Change to same indices as other DataFrame.
#    5424
#    5425     Examples
#    5426     --------
#    5427     ``DataFrame.reindex`` supports two calling conventions
#    5428
#    5429     * ``(index=index_labels, columns=column_labels, ...)``
#    5430     * ``(labels, axis={{'index', 'columns'}}, ...)``
#    5431
#    5432     We *highly* recommend using keyword arguments to clarify your
#    5433     intent.
#    5434
#    5435     Create a dataframe with some fictional data.
#    5436
#    5437     >>> index = ['Firefox', 'Chrome', 'Safari', 'IE10', 'Konqueror']
#    5438     >>> df = pd.DataFrame({{'http_status': [200, 200, 404, 404, 301],
#    5439     ...                   'response_time': [0.04, 0.02, 0.07, 0.08, 1.0]}},
#    5440     ...                   index=index)
#    5441     >>> df
#    5442                http_status  response_time
#    5443     Firefox            200           0.04
#    5444     Chrome             200           0.02
#    5445     Safari             404           0.07
#    5446     IE10               404           0.08
#    5447     Konqueror          301           1.00
#    5448
#    5449     Create a new index and reindex the dataframe. By default
#    5450     values in the new index that do not have corresponding
#    5451     records in the dataframe are assigned ``NaN``.
#    5452
#    5453     >>> new_index = ['Safari', 'Iceweasel', 'Comodo Dragon', 'IE10',
#    5454     ...              'Chrome']
#    5455     >>> df.reindex(new_index)
#    5456                    http_status  response_time
#    5457     Safari               404.0           0.07
#    5458     Iceweasel              NaN            NaN
#    5459     Comodo Dragon          NaN            NaN
#    5460     IE10                 404.0           0.08
#    5461     Chrome               200.0           0.02
#    5462
#    5463     We can fill in the missing values by passing a value to
#    5464     the keyword ``fill_value``. Because the index is not monotonically
#    5465     increasing or decreasing, we cannot use arguments to the keyword
#    5466     ``method`` to fill the ``NaN`` values.
#    5467
#    5468     >>> df.reindex(new_index, fill_value=0)
#    5469                    http_status  response_time
#    5470     Safari                 404           0.07
#    5471     Iceweasel                0           0.00
#    5472     Comodo Dragon            0           0.00
#    5473     IE10                   404           0.08
#    5474     Chrome                 200           0.02
#    5475
#    5476     >>> df.reindex(new_index, fill_value='missing')
#    5477                   http_status response_time
#    5478     Safari                404          0.07
#    5479     Iceweasel         missing       missing
#    5480     Comodo Dragon     missing       missing
#    5481     IE10                  404          0.08
#    5482     Chrome                200          0.02
#    5483
#    5484     We can also reindex the columns.
#    5485
#    5486     >>> df.reindex(columns=['http_status', 'user_agent'])
#    5487                http_status  user_agent
#    5488     Firefox            200         NaN
#    5489     Chrome             200         NaN
#    5490     Safari             404         NaN
#    5491     IE10               404         NaN
#    5492     Konqueror          301         NaN
#    5493
#    5494     Or we can use "axis-style" keyword arguments
#    5495
#    5496     >>> df.reindex(['http_status', 'user_agent'], axis="columns")
#    5497                http_status  user_agent
#    5498     Firefox            200         NaN
#    5499     Chrome             200         NaN
#    5500     Safari             404         NaN
#    5501     IE10               404         NaN
#    5502     Konqueror          301         NaN
#    5503
#    5504     To further illustrate the filling functionality in
#    5505     ``reindex``, we will create a dataframe with a
#    5506     monotonically increasing index (for example, a sequence
#    5507     of dates).
#    5508
#    5509     >>> date_index = pd.date_range('1/1/2010', periods=6, freq='D')
#    5510     >>> df2 = pd.DataFrame({{"prices": [100, 101, np.nan, 100, 89, 88]}},
#    5511     ...                    index=date_index)
#    5512     >>> df2
#    5513                 prices
#    5514     2010-01-01   100.0
#    5515     2010-01-02   101.0
#    5516     2010-01-03     NaN
#    5517     2010-01-04   100.0
#    5518     2010-01-05    89.0
#    5519     2010-01-06    88.0
#    5520
# -> 5521     Suppose we decide to expand the dataframe to cover a wider
#    5522     date range.
#    5523
#    5524     >>> date_index2 = pd.date_range('12/29/2009', periods=10, freq='D')
#    5525     >>> df2.reindex(date_index2)
#    5526                 prices
#    5527     2009-12-29     NaN
#    5528     2009-12-30     NaN
#    5529     2009-12-31     NaN
#    5530     2010-01-01   100.0
#    5531     2010-01-02   101.0
#    5532     2010-01-03     NaN
#    5533     2010-01-04   100.0
#    5534     2010-01-05    89.0
#    5535     2010-01-06    88.0
#    5536     2010-01-07     NaN
#    5537
#    5538     The index entries that did not have a value in the original data frame
#    5539     (for example, '2009-12-29') are by default filled with ``NaN``.
#    5540     If desired, we can fill in the missing values using one of several
#    5541     options.
#    5542
#    5543     For example, to back-propagate the last valid value to fill the ``NaN``
#    5544     values, pass ``bfill`` as an argument to the ``method`` keyword.
#    5545
#    5546     >>> df2.reindex(date_index2, method='bfill')
#    5547                 prices
#    5548     2009-12-29   100.0
#    5549     2009-12-30   100.0
#    5550     2009-12-31   100.0
#    5551     2010-01-01   100.0
#    5552     2010-01-02   101.0
#    5553     2010-01-03     NaN
#    5554     2010-01-04   100.0
#    5555     2010-01-05    89.0
#    5556     2010-01-06    88.0
#    5557     2010-01-07     NaN
#    5558
#    5559     Please note that the ``NaN`` value present in the original dataframe
#    5560     (at index value 2010-01-03) will not be filled by any of the
#    5561     value propagation schemes. This is because filling while reindexing
#    5562     does not look at dataframe values, but only compares the original and
#    5563     desired indexes. If you do want to fill in the ``NaN`` values present
#    5564     in the original dataframe, use the ``fillna()`` method.
#    5565
#    5566     See the :ref:`user guide <basics.reindexing>` for more.
#    5567     """
#    5568     # TODO: Decide if we care about having different examples for different
#    5569     # kinds
#    5571     if index is not None and columns is not None and labels is not None:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/generic.py:5544, in _reindex_axes(self, axes, level, limit, tolerance, method, fill_value, copy)
#    5343 @doc(
#    5344     klass=_shared_doc_kwargs["klass"],
#    5345     optional_reindex="",
#    (...)
#    5359     tolerance=None,
#    5360 ) -> Self:
#    5361     """
#    5362     Conform {klass} to new index with optional filling logic.
#    5363
#    5364     Places NA/NaN in locations having no value in the previous index. A new object
#    5365     is produced unless the new index is equivalent to the current one and
#    5366     ``copy=False``.
#    5367
#    5368     Parameters
#    5369     ----------
#    5370     {optional_reindex}
#    5371     method : {{None, 'backfill'/'bfill', 'pad'/'ffill', 'nearest'}}
#    5372         Method to use for filling holes in reindexed DataFrame.
#    5373         Please note: this is only applicable to DataFrames/Series with a
#    5374         monotonically increasing/decreasing index.
#    5375
#    5376         * None (default): don't fill gaps
#    5377         * pad / ffill: Propagate last valid observation forward to next
#    5378           valid.
#    5379         * backfill / bfill: Use next valid observation to fill gap.
#    5380         * nearest: Use nearest valid observations to fill gap.
#    5381
#    5382     copy : bool, default True
#    5383         Return a new object, even if the passed indexes are the same.
#    5384
#    5385         .. note::
#    5386             The `copy` keyword will change behavior in pandas 3.0.
#    5387             `Copy-on-Write
#    5388             <https://pandas.pydata.org/docs/dev/user_guide/copy_on_write.html>`__
#    5389             will be enabled by default, which means that all methods with a
#    5390             `copy` keyword will use a lazy copy mechanism to defer the copy and
#    5391             ignore the `copy` keyword. The `copy` keyword will be removed in a
#    5392             future version of pandas.
#    5393
#    5394             You can already get the future behavior and improvements through
#    5395             enabling copy on write ``pd.options.mode.copy_on_write = True``
#    5396     level : int or name
#    5397         Broadcast across a level, matching Index values on the
#    5398         passed MultiIndex level.
#    5399     fill_value : scalar, default np.nan
#    5400         Value to use for missing values. Defaults to NaN, but can be any
#    5401         "compatible" value.
#    5402     limit : int, default None
#    5403         Maximum number of consecutive elements to forward or backward fill.
#    5404     tolerance : optional
#    5405         Maximum distance between original and new labels for inexact
#    5406         matches. The values of the index at the matching locations most
#    5407         satisfy the equation ``abs(index[indexer] - target) <= tolerance``.
#    5408
#    5409         Tolerance may be a scalar value, which applies the same tolerance
#    5410         to all values, or list-like, which applies variable tolerance per
#    5411         element. List-like includes list, tuple, array, Series, and must be
#    5412         the same size as the index and its dtype must exactly match the
#    5413         index's type.
#    5414
#    5415     Returns
#    5416     -------
#    5417     {klass} with changed index.
#    5418
#    5419     See Also
#    5420     --------
#    5421     DataFrame.set_index : Set row labels.
#    5422     DataFrame.reset_index : Remove row labels or move them to new columns.
#    5423     DataFrame.reindex_like : Change to same indices as other DataFrame.
#    5424
#    5425     Examples
#    5426     --------
#    5427     ``DataFrame.reindex`` supports two calling conventions
#    5428
#    5429     * ``(index=index_labels, columns=column_labels, ...)``
#    5430     * ``(labels, axis={{'index', 'columns'}}, ...)``
#    5431
#    5432     We *highly* recommend using keyword arguments to clarify your
#    5433     intent.
#    5434
#    5435     Create a dataframe with some fictional data.
#    5436
#    5437     >>> index = ['Firefox', 'Chrome', 'Safari', 'IE10', 'Konqueror']
#    5438     >>> df = pd.DataFrame({{'http_status': [200, 200, 404, 404, 301],
#    5439     ...                   'response_time': [0.04, 0.02, 0.07, 0.08, 1.0]}},
#    5440     ...                   index=index)
#    5441     >>> df
#    5442                http_status  response_time
#    5443     Firefox            200           0.04
#    5444     Chrome             200           0.02
#    5445     Safari             404           0.07
#    5446     IE10               404           0.08
#    5447     Konqueror          301           1.00
#    5448
#    5449     Create a new index and reindex the dataframe. By default
#    5450     values in the new index that do not have corresponding
#    5451     records in the dataframe are assigned ``NaN``.
#    5452
#    5453     >>> new_index = ['Safari', 'Iceweasel', 'Comodo Dragon', 'IE10',
#    5454     ...              'Chrome']
#    5455     >>> df.reindex(new_index)
#    5456                    http_status  response_time
#    5457     Safari               404.0           0.07
#    5458     Iceweasel              NaN            NaN
#    5459     Comodo Dragon          NaN            NaN
#    5460     IE10                 404.0           0.08
#    5461     Chrome               200.0           0.02
#    5462
#    5463     We can fill in the missing values by passing a value to
#    5464     the keyword ``fill_value``. Because the index is not monotonically
#    5465     increasing or decreasing, we cannot use arguments to the keyword
#    5466     ``method`` to fill the ``NaN`` values.
#    5467
#    5468     >>> df.reindex(new_index, fill_value=0)
#    5469                    http_status  response_time
#    5470     Safari                 404           0.07
#    5471     Iceweasel                0           0.00
#    5472     Comodo Dragon            0           0.00
#    5473     IE10                   404           0.08
#    5474     Chrome                 200           0.02
#    5475
#    5476     >>> df.reindex(new_index, fill_value='missing')
#    5477                   http_status response_time
#    5478     Safari                404          0.07
#    5479     Iceweasel         missing       missing
#    5480     Comodo Dragon     missing       missing
#    5481     IE10                  404          0.08
#    5482     Chrome                200          0.02
#    5483
#    5484     We can also reindex the columns.
#    5485
#    5486     >>> df.reindex(columns=['http_status', 'user_agent'])
#    5487                http_status  user_agent
#    5488     Firefox            200         NaN
#    5489     Chrome             200         NaN
#    5490     Safari             404         NaN
#    5491     IE10               404         NaN
#    5492     Konqueror          301         NaN
#    5493
#    5494     Or we can use "axis-style" keyword arguments
#    5495
#    5496     >>> df.reindex(['http_status', 'user_agent'], axis="columns")
#    5497                http_status  user_agent
#    5498     Firefox            200         NaN
#    5499     Chrome             200         NaN
#    5500     Safari             404         NaN
#    5501     IE10               404         NaN
#    5502     Konqueror          301         NaN
#    5503
#    5504     To further illustrate the filling functionality in
#    5505     ``reindex``, we will create a dataframe with a
#    5506     monotonically increasing index (for example, a sequence
#    5507     of dates).
#    5508
#    5509     >>> date_index = pd.date_range('1/1/2010', periods=6, freq='D')
#    5510     >>> df2 = pd.DataFrame({{"prices": [100, 101, np.nan, 100, 89, 88]}},
#    5511     ...                    index=date_index)
#    5512     >>> df2
#    5513                 prices
#    5514     2010-01-01   100.0
#    5515     2010-01-02   101.0
#    5516     2010-01-03     NaN
#    5517     2010-01-04   100.0
#    5518     2010-01-05    89.0
#    5519     2010-01-06    88.0
#    5520
#    5521     Suppose we decide to expand the dataframe to cover a wider
#    5522     date range.
#    5523
#    5524     >>> date_index2 = pd.date_range('12/29/2009', periods=10, freq='D')
#    5525     >>> df2.reindex(date_index2)
#    5526                 prices
#    5527     2009-12-29     NaN
#    5528     2009-12-30     NaN
#    5529     2009-12-31     NaN
#    5530     2010-01-01   100.0
#    5531     2010-01-02   101.0
#    5532     2010-01-03     NaN
#    5533     2010-01-04   100.0
#    5534     2010-01-05    89.0
#    5535     2010-01-06    88.0
#    5536     2010-01-07     NaN
#    5537
#    5538     The index entries that did not have a value in the original data frame
#    5539     (for example, '2009-12-29') are by default filled with ``NaN``.
#    5540     If desired, we can fill in the missing values using one of several
#    5541     options.
#    5542
#    5543     For example, to back-propagate the last valid value to fill the ``NaN``
# -> 5544     values, pass ``bfill`` as an argument to the ``method`` keyword.
#    5545
#    5546     >>> df2.reindex(date_index2, method='bfill')
#    5547                 prices
#    5548     2009-12-29   100.0
#    5549     2009-12-30   100.0
#    5550     2009-12-31   100.0
#    5551     2010-01-01   100.0
#    5552     2010-01-02   101.0
#    5553     2010-01-03     NaN
#    5554     2010-01-04   100.0
#    5555     2010-01-05    89.0
#    5556     2010-01-06    88.0
#    5557     2010-01-07     NaN
#    5558
#    5559     Please note that the ``NaN`` value present in the original dataframe
#    5560     (at index value 2010-01-03) will not be filled by any of the
#    5561     value propagation schemes. This is because filling while reindexing
#    5562     does not look at dataframe values, but only compares the original and
#    5563     desired indexes. If you do want to fill in the ``NaN`` values present
#    5564     in the original dataframe, use the ``fillna()`` method.
#    5565
#    5566     See the :ref:`user guide <basics.reindexing>` for more.
#    5567     """
#    5568     # TODO: Decide if we care about having different examples for different
#    5569     # kinds
#    5571     if index is not None and columns is not None and labels is not None:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/indexes/base.py:4433, in reindex(self, target, method, level, limit, tolerance)
#    4430         else:
#    4431             indexer, _ = self.get_indexer_non_unique(target)
# -> 4433 target = self._wrap_reindex_result(target, indexer, preserve_names)
#    4434 return target, indexer
#
# ValueError: cannot reindex on an axis with duplicate labels
